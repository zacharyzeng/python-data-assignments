# %%
# with open("trade-wars-news1.txt", "r") as f1:
#     with open("trade-wars-news2.txt", "r") as f2:
#         with open("trade-wars-news3.txt", "r") as f3:
#             with open("trade-wars-news4.txt", "r") as f4:
#                 with open("trade-wars-news5.txt", "r") as f5:
#                     contents1=f1.readlines()
#                     contents2=f2.readlines()
#                     contents3=f3.readlines()
#                     contents4=f4.readlines()
#                     contents5=f5.readlines()
#                     str = "contents1"
#                     print (str.split( ))

# %%
# import csv

# texts = ['trade-wars-news1.txt','trade-wars-news2.txt','trade-wars-news3.txt','trade-wars-news4.txt','trade-wars-news5.txt']
# trade_wars_news = []
# for i in texts:
#     f = open(i,'r')
#     contents=f.read()
#     trade_wars_news.append(contents)
# trade_wars_news

# with open("trade-wars-news1.txt", "r") as f1:
#     contents1=f1.read()
# #     print(contents1)
# contents1.split()
# #     print(contents1.split())
# list = contents1.split()
# dict_words_frequency={}
# for m in list:
#     dict_words_frequency[m]=list.count(m)
# # print(dict_words_frequency)

# list_words_frequency = []
# for i in dict_words_frequency:
#     f = dict_words_frequency[i]
    
#     list_words_frequency.append((i,f))
# # print(list_words_frequency)

# rank = list_words_frequency
# rank_list = sorted(rank,key=lambda a:a[1],reverse = True)
# rank_list[0:15]

# # keywords = dict_words_frequency.sorted()
# # keywords


# #     dict = dict.fromkeys(seq)
# #     dict_keys = dict.keys()
# #     count = {}
# #     for items in dict_keys:

# %%
import csv

texts = ['trade-wars-news1.txt','trade-wars-news2.txt','trade-wars-news3.txt','trade-wars-news4.txt','trade-wars-news5.txt']
trade_wars_news = []
for i in texts:
    f = open(i,'r')
    contents=f.read()
    trade_wars_news.append(contents)
# trade_wars_news

all_articles = []
for i in range(5):                    ## helped by helper
    words = trade_wars_news[i].split()
    for m in words:
        all_articles.append(m)
# all_articles


list = all_articles
dict_words_frequency={}
for n in list:
    dict_words_frequency[n]=list.count(n)
#dict_words_frequency

list_words_frequency = []
for i in dict_words_frequency:
    f = dict_words_frequency[i]
    list_words_frequency.append((i,f))
# print(list_words_frequency)

rank = list_words_frequency
rank_list = sorted(rank,key=lambda a:a[1],reverse = True) ## Google for the syntax
rank_list[0:15]

with open('keywords.csv','w',newline='') as g:
    writer = csv.writer(g)
    header = ['Keyword','Frequency']
    writer.writerow(header)
    writer.writerows(rank_list[0:15])

# %% [markdown]
# ## Bonus: Handle the stop words

# %%
import csv

texts = ['trade-wars-news1.txt','trade-wars-news2.txt','trade-wars-news3.txt','trade-wars-news4.txt','trade-wars-news5.txt']
trade_wars_news = []
for i in texts:
    f = open(i,'r')
    contents=f.read()
    trade_wars_news.append(contents)
# trade_wars_news

all_articles = []
for i in range(5):                    ## helped by helper
    words = trade_wars_news[i].split()
    for m in words:
        all_articles.append(m)
# all_articles


list = all_articles
dict_words_frequency={}
for n in list:
    dict_words_frequency[n]=list.count(n)
#dict_words_frequency

list_words_frequency = []
for i in dict_words_frequency:
    f = dict_words_frequency[i]
    
    list_words_frequency.append((i,f))
# print(list_words_frequency)

rank = list_words_frequency
rank_list = sorted(rank,key=lambda a:a[1],reverse = True) ## Google for the syntax
# rank_list[0:15]
rank_list

# stop_words = ["the", "and", "of", "a", "in"]
# # filtered_word_list =  # make a copy of the word_list
# for word in rank_list: # iterate over word_list
#     if word in stop_words: 
#         word.remove(stop_words)
# rank_list
    
# with open('keywords.csv','w',newline='') as g:
#     writer = csv.writer(g)
#     header = ['Keyword','Frequency']
#     writer.writerow(header)
#     writer.writerows(rank_list[0:15])
# Out:
# [('the', 327),
#  ('to', 187),
#  ('of', 149),
#  ('and', 132),
#  ('a', 124),
#  ('in', 99),
#  ('that', 68),
#  ('is', 58),
#  ('as', 53),
#  ('on', 52),
#  ('China', 51),
#  ('with', 49),
#  ('trade', 47),
#  ('US', 47),
#  ('Chinese', 44),
#  ('The', 37),
#  ('for', 35),
#  ('it', 33),
#  ('has', 31),
#  ('are', 31),
#  ('not', 28),
#  ('have', 28),
#  ('Trump', 28),
#  ('its', 27),
#  ('from', 25),
#  ('war', 23),
#  ('would', 22),
#  ('be', 20),
#  ('at', 20),
#  ('China’s', 19),
#  ('an', 19),
#  ('which', 18),
#  ('by', 17),
#  ('up', 16),
#  ('this', 16),
#  ('tariffs', 16),
#  ('said', 16),
#  ('U.S.', 16),
#  ('also', 15),
#  ('more', 15),
#  ('will', 15),
#  ('about', 14),
#  ('American', 14),
#  ('against', 14),
#  ('last', 13),
#  ('was', 13),
#  ('Beijing', 13),
#  ('been', 12),
#  ('they', 12),
#  ('see', 11),
#  ('economic', 11),
#  ('new', 10),
#  ('if', 10),
#  ('In', 10),
#  ('I', 10),
#  ('but', 10),
#  ('he', 10),
#  ('deal', 10),
#  ('President', 10),
#  ('political', 10),
#  ('all', 9),
#  ('billion', 9),
#  ('out', 9),
#  ('so', 9),
#  ('could', 9),
#  ('China,', 9),
#  ('administration', 9),
#  ('than', 8),
#  ('who', 8),
#  ('can', 8),
#  ('had', 8),
#  ('most', 8),
#  ('Pence', 8),
#  ('China.', 8),
#  ('his', 8),
#  ('we', 8),
#  ('United', 8),
#  ('Soviet', 8),
#  ('America', 8),
#  ('2018', 7),
#  ('going', 7),
#  ('while', 7),
#  ('(link', 7),
#  ('how', 7),
#  ('economy', 7),
#  ('their', 7),
#  ('long', 7),
#  ('Canada', 7),
#  ('other', 7),
#  ('one', 7),
#  ('Beijing’s', 7),
#  ('between', 7),
#  ('or', 7),
#  ('two', 7),
#  ('over', 7),
#  ('global', 7),
#  ('Russia', 7),
#  ('America’s', 7),
#  ('Global', 7),
#  ('Times', 7),
#  ('my', 6),
#  ('first', 6),
#  ('willing', 6),
#  ('stock', 6),
#  ('because', 6),
#  ('foreign', 6),
#  ('including', 6),
#  ('This', 6),
#  ('then', 6),
#  ('countries', 6),
#  ('make', 6),
#  ('even', 6),
#  ('itself', 6),
#  ('any', 6),
#  ('Mike', 6),
#  ('per', 6),
#  ('cent', 6),
#  ('do', 6),
#  ('just', 6),
#  ('But', 6),
#  ('Russian', 6),
#  ('enemy', 6),
#  ('cosmopolitan', 6),
#  ('might', 5),
#  ('And', 5),
#  ('goods', 5),
#  ('state', 5),
#  ('no', 5),
#  ('become', 5),
#  ('common', 5),
#  ('after', 5),
#  ('wrote', 5),
#  ('US,', 5),
#  ('As', 5),
#  ('recent', 5),
#  ('pressure', 5),
#  ('Trade', 5),
#  ('domestic', 5),
#  ('talks', 5),
#  ('another', 5),
#  ('should', 5),
#  ('further', 5),
#  ('Zhong', 5),
#  ('Pompeo', 5),
#  ('there', 5),
#  ('into', 5),
#  ('Donald', 5),
#  ('such', 5),
#  ('conflict', 5),
#  ('midterm', 5),
#  ('Union', 5),
#  ('much', 5),
#  ('efforts', 5),
#  ('world', 5),
#  ('REIHAN', 5),
#  ('SALAM', 5),
#  ('conservatives', 5),
#  ('Putin', 5),
#  ('nationalist', 5),
#  ('speech', 5),
#  ('people', 4),
#  ('public', 4),
#  ('year,', 4),
#  ('both', 4),
#  ('put', 4),
#  ('“The', 4),
#  ('show', 4),
#  ('Chinese)', 4),
#  ('That', 4),
#  ('next', 4),
#  ('point', 4),
#  ('central', 4),
#  ('user', 4),
#  ('himself', 4),
#  ('far', 4),
#  ('now', 4),
#  ('tariffs,', 4),
#  ('“I', 4),
#  ('It', 4),
#  ('A', 4),
#  ('NAFTA', 4),
#  ('some', 4),
#  ('difficult', 4),
#  ('trade,', 4),
#  ('want', 4),
#  ('Mexico', 4),
#  ('agreement', 4),
#  ('wants', 4),
#  ('each', 4),
#  ('demands', 4),
#  ('Minister', 4),
#  ('US.', 4),
#  ('know', 4),
#  ('free', 4),
#  ('line', 4),
#  ('whether', 4),
#  ('advantage', 4),
#  ('Secretary', 4),
#  ('State', 4),
#  ('Foreign', 4),
#  ('Wang', 4),
#  ('were', 4),
#  ('tariff', 4),
#  ('change', 4),
#  ('technology', 4),
#  ('contain', 4),
#  ('market', 4),
#  ('country', 4),
#  ('business', 4),
#  ('Trump’s', 4),
#  ('take', 4),
#  ('European', 4),
#  ('those', 4),
#  ('talking', 4),
#  ('strategy', 4),
#  ('summit', 4),
#  ('"We', 4),
#  ('Japan', 4),
#  ('early', 4),
#  ('relationship', 4),
#  ('States', 4),
#  ('question', 4),
#  ('president', 4),
#  ('when', 4),
#  ('different', 4),
#  ('rising', 4),
#  ('our', 4),
#  ('part', 4),
#  ('threat', 4),
#  ('democracies', 4),
#  ('commitment', 4),
#  ('cannot', 4),
#  ('What', 3),
#  ('9,', 3),
#  ('increasing', 3),
#  ('same', 3),
#  ('national', 3),
#  ('always', 3),
#  ('through', 3),
#  ('greater', 3),
#  ('state-run', 3),
#  ('doesn’t', 3),
#  ('people.', 3),
#  ('go', 3),
#  ('requirement', 3),
#  ('time', 3),
#  ('seen', 3),
#  ('war.', 3),
#  ('markets', 3),
#  ('many', 3),
#  ('officials', 3),
#  ('asked', 3),
#  ('year.', 3),
#  ('worried', 3),
#  ('While', 3),
#  ('need', 3),
#  ('It’s', 3),
#  ('Chinese).', 3),
#  ('oil', 3),
#  ('nuts', 3),
#  ('top', 3),
#  ('based', 3),
#  ('He', 3),
#  ('war,', 3),
#  ('up.', 3),
#  ('may', 3),
#  ('manufacturing', 3),
#  ('better', 3),
#  ('imports.', 3),
#  ('Mexico,', 3),
#  ('front', 3),
#  ('Americans', 3),
#  ('so-called', 3),
#  ('back', 3),
#  ('stance', 3),
#  ('tensions', 3),
#  ('taken', 3),
#  ('Monday,', 3),
#  ('exchange', 3),
#  ('told', 3),
#  ('must', 3),
#  ('Washington', 3),
#  ('intellectual', 3),
#  ('rights', 3),
#  ('25', 3),
#  ('transfer', 3),
#  ('side', 3),
#  ('time,', 3),
#  ('accusations', 3),
#  ('attempting', 3),
#  ('elections.', 3),
#  ('warned', 3),
#  ('anytime', 3),
#  ('South', 3),
#  ('Union.', 3),
#  ('finance', 3),
#  ('chiefs', 3),
#  ('week.', 3),
#  ('If', 3),
#  ('Beijing,', 3),
#  ('chief', 3),
#  ('still', 3),
#  ('clear', 3),
#  ('campaign', 3),
#  ('potential', 3),
#  ('made', 3),
#  ('pain', 3),
#  ('elections', 3),
#  ('why', 3),
#  ('party-state', 3),
#  ('seeking', 3),
#  ('influence', 3),
#  ('outcome', 3),
#  ('democratic', 3),
#  ('world’s', 3),
#  ('orienting', 3),
#  ('Huntington', 3),
#  ('grand', 3),
#  ('creedal', 3),
#  ('identity', 3),
#  ('freedom', 3),
#  ('did', 3),
#  ('among', 3),
#  ('defines', 3),
#  ('cold', 3),
#  ('serves', 3),
#  ('act', 3),
#  ('power', 3),
#  ('open', 3),
#  ('Western', 3),
#  ('liberals', 3),
#  ('toward', 3),
#  ('especially', 3),
#  ('Cold', 3),
#  ('took', 3),
#  ('editorial', 3),
#  ('Hudson', 3),
#  ('messed', 2),
#  ('think', 2),
#  ('By', 2),
#  ('win', 2),
#  ('support', 2),
#  ('sides', 2),
#  ('goods.', 2),
#  ('imports,', 2),
#  ('done', 2),
#  ('worth', 2),
#  ('keep', 2),
#  ('strongest', 2),
#  ('spirit', 2),
#  ('run', 2),
#  ('opinion', 2),
#  ('deeply', 2),
#  ('without', 2),
#  ('comment', 2),
#  ('acknowledge', 2),
#  ('added', 2),
#  ('half', 2),
#  ('off', 2),
#  ('growth.', 2),
#  ('worrying', 2),
#  ('come.', 2),
#  ('yuan', 2),
#  ('On', 2),
#  ('Monday', 2),
#  ('day', 2),
#  ('fell', 2),
#  ('(paywall)', 2),
#  ('three', 2),
#  ('tumble', 2),
#  ('bank', 2),
#  ('move', 2),
#  ('trying', 2),
#  ('boost', 2),
#  ('haven’t', 2),
#  ('“This', 2),
#  ('year', 2),
#  ('Weibo,', 2),
#  ('working', 2),
#  ('firm', 2),
#  ('Beijing.', 2),
#  ('When', 2),
#  ('work', 2),
#  ('markets.', 2),
#  ('help', 2),
#  ('making', 2),
#  ('life', 2),
#  ('hundreds', 2),
#  ('thousands', 2),
#  ('hard', 2),
#  ('like', 2),
#  ('prices', 2),
#  ('suddenly', 2),
#  ('expensive', 2),
#  ('ran', 2),
#  ('she', 2),
#  ('found', 2),
#  ('cost', 2),
#  ('war,”', 2),
#  ('feel', 2),
#  ('imports', 2),
#  ('August.', 2),
#  ('environment', 2),
#  ('good.', 2),
#  ('there’s', 2),
#  ('real', 2),
#  ('won’t', 2),
#  ('before', 2),
#  ('can’t', 2),
#  ('businesses', 2),
#  ('hit', 2),
#  ('firms', 2),
#  ('50', 2),
#  ('response', 2),
#  ('fact,', 2),
#  ('Agreement', 2),
#  ('argument', 2),
#  ('elements', 2),
#  ('key', 2),
#  ('growth', 2),
#  ('terms', 2),
#  ('wars', 2),
#  ('build', 2),
#  ('At', 2),
#  ('end', 2),
#  ('September,', 2),
#  ('‘non-market-oriented', 2),
#  ('needs', 2),
#  ('knows', 2),
#  ('give', 2),
#  ('building', 2),
#  ('anti-China', 2),
#  ('gave', 2),
#  ('am', 2),
#  ('Japan,', 2),
#  ('highly', 2),
#  ('suggest', 2),
#  ('major', 2),
#  ('current', 2),
#  ('policies', 2),
#  ('instead', 2),
#  ('down', 2),
#  ('said,', 2),
#  ('keeps', 2),
#  ('down.', 2),
#  ('history', 2),
#  ('nation', 2),
#  ('times', 2),
#  ('never', 2),
#  ('rise', 2),
#  ('break', 2),
#  ('resolve', 2),
#  ('yet', 2),
#  ('following', 2),
#  ('month', 2),
#  ('strong', 2),
#  ('whose', 2),
#  ('Companies', 2),
#  ('consumers', 2),
#  ('best', 2),
#  ('testy', 2),
#  ('hurt', 2),
#  ('stop', 2),
#  ('de-escalate', 2),
#  ('punitive', 2),
#  ('property', 2),
#  ('role', 2),
#  ('state-owned', 2),
#  ('enterprises.', 2),
#  ('imposed', 2),
#  ('US$50', 2),
#  ('10', 2),
#  ('set', 2),
#  ('does', 2),
#  ('threatened', 2),
#  ('Yi', 2),
#  ('technologies', 2),
#  ('reiterated', 2),
#  ('said.', 2),
#  ('progress', 2),
#  ('opening', 2),
#  ('beyond', 2),
#  ('relations', 2),
#  ('interfere', 2),
#  ('using', 2),
#  ('undermine', 2),
#  ('playbook', 2),
#  ('Bali,', 2),
#  ('—', 2),
#  ('soon.', 2),
#  ('week,', 2),
#  ('given', 2),
#  ('hold', 2),
#  ('Korea,', 2),
#  ('him', 2),
#  ('impose', 2),
#  ('China,"', 2),
#  ('senior', 2),
#  ('fellow', 2),
#  ("Trump's", 2),
#  ('likely', 2),
#  ('damage', 2),
#  ('protracted', 2),
#  ('"The', 2),
#  ('stakes', 2),
#  ('International', 2),
#  ('deals', 2),
#  ('reach', 2),
#  ('again,', 2),
#  ('what', 2),
#  ('coalition', 2),
#  ('Europe', 2),
#  ('Paris', 2),
#  ('climate', 2),
#  ('reference', 2),
#  ('States.', 2),
#  ('approach', 2),
#  ('allies', 2),
#  ('address', 2),
#  ('economies', 2),
#  ('weakened', 2),
#  ('exports', 2),
#  ('mean', 2),
#  ('them', 2),
#  ('tariffs.', 2),
#  ('looms', 2),
#  ('government', 2),
#  ('ways', 2),
#  ('concerns', 2),
#  ('relies', 2),
#  ('less', 2),
#  ('already', 2),
#  ('How', 2),
#  ('For', 2),
#  ('part,', 2),
#  ('Robert', 2),
#  ('place,', 2),
#  ('you', 2),
#  ('Xi', 2),
#  ('Jinping', 2),
#  ('leaders', 2),
#  ('soon', 2),
#  ('appear', 2),
#  ('Is', 2),
#  ('consequences', 2),
#  ('Vice', 2),
#  ('wide-ranging', 2),
#  ('hostility', 2),
#  ('regimes', 2),
#  ('around', 2),
#  ('world.', 2),
#  ('Yet', 2),
#  ('outside', 2),
#  ('“China', 2),
#  ('shift', 2),
#  ('administration’s', 2),
#  ('Pence,', 2),
#  ('politics', 2),
#  ('criticism', 2),
#  ('desperate', 2),
#  ('Against', 2),
#  ('All', 2),
#  ('upcoming', 2),
#  ('election', 2),
#  ('challenge', 2),
#  ('observers', 2),
#  ('Russia’s', 2),
#  ('seems', 2),
#  ('observed,', 2),
#  ('very', 2),
#  ('large', 2),
#  ('numbers', 2),
#  ('themselves', 2),
#  ('powers', 2),
#  ('once', 2),
#  ('shape.', 2),
#  ('collapse', 2),
#  ('defined', 2),
#  ('days', 2),
#  ('British', 2),
#  ('under', 2),
#  ('years', 2),
#  ('often', 2),
#  ('cohesion', 2),
#  ('find', 2),
#  ('divided', 2),
#  ('whom', 2),
#  ('supposed', 2),
#  ('understand', 2),
#  ('liberal', 2),
#  ('Europe,', 2),
#  ('2016', 2),
#  ('forces', 2),
#  ('gay', 2),
#  ('=', 2),
#  ('liberalism', 2),
#  ('defender', 2),
#  ('natural', 2),
#  ('ally', 2),
#  ('defend', 2),
#  ('invites', 2),
#  ('warier', 2),
#  ('populist', 2),
#  ('these', 2),
#  ('party-state,', 2),
#  ('exactly', 2),
#  ('doing', 2),
#  ('elite', 2),
#  ('sees', 2),
#  ('integration', 2),
#  ('choose', 2),
#  ('One', 2),
#  ('industrial', 2),
#  ('strategic', 2),
#  ('imagine', 2),
#  ('ordinary', 2),
#  ('stands', 2),
#  ('welcome', 2),
#  ('sacrifice', 2),
#  ('Which', 2),
#  ('Pence’s', 2),
#  ('Institute', 2),
#  ('compared', 2),
#  ('Churchill’s', 2),
#  ('authoritarian', 2),
#  ('calm', 2),
#  ('unique', 2),
#  ('delivered', 2),
#  ('Thucydides', 2),
#  ('reason', 2),
#  ('distract', 2),
#  ('Russiagate', 2),
#  ('–', 2),
#  ('only', 2),
#  ('respect', 2),
#  ('“Utterly', 1),
#  ('life”:', 1),
#  ('really', 1),
#  ('Guardian', 1),
#  ('Echo', 1),
#  ('HuangOctober', 1),
#  ('ardent', 1),
#  ('determination', 1),
#  ('like.', 1),
#  ('Since', 1),
#  ('entered', 1),
#  ('earnest', 1),
#  ('tit-for-tat', 1),
#  ('$250', 1),
#  ('$110', 1),
#  ('running', 1),
#  ('retaliation', 1),
#  ('going,', 1),
#  ('weapon', 1),
#  ('“war', 1),
#  ('fate”', 1),
#  ('people,', 1),
#  ('according', 1),
#  ('media.', 1),
#  ('heroism', 1),
#  ('‘being', 1),
#  ('concern', 1),
#  ('enjoy', 1),
#  ('oneself’', 1),
#  ('blood,', 1),
#  ('includes', 1),
#  ('‘sacrificing', 1),
#  ('one’s', 1),
#  ('interest', 1),
#  ('good', 1),
#  ("public,'”", 1),
#  ('piece', 1),
#  ('posted', 1),
#  ('People’s', 1),
#  ('Daily', 1),
#  ('July', 1),
#  ('10.', 1),
#  ('“Facing', 1),
#  ('‘war', 1),
#  ('fate,’', 1),
#  ('aware', 1),
#  ('‘there’s', 1),
#  ('home', 1),
#  ('country,’', 1),
#  ('bear', 1),
#  ('temporary', 1),
#  ('losses.”', 1),
#  ('painful', 1),
#  ('Economists', 1),
#  ('estimate', 1),
#  ('latest', 1),
#  ('25%', 1),
#  ('shave', 1),
#  ('percentage', 1),
#  ('Online,', 1),
#  ('sharing', 1),
#  ('they’re', 1),
#  ('experiencing', 1),
#  ('impacts', 1),
#  ('far,', 1),
#  ('what’s', 1),
#  ('Stocks', 1),
#  ('tumble,', 1),
#  ('devalues', 1),
#  ('(Oct.7),', 1),
#  ('Golden', 1),
#  ('Week', 1),
#  ('holiday,', 1),
#  ('stocks', 1),
#  ('sharply.', 1),
#  ('benchmark', 1),
#  ('Shanghai', 1),
#  ('Composite', 1),
#  ('Index', 1),
#  ('3.7%—its', 1),
#  ('biggest', 1),
#  ('single-day', 1),
#  ('loss', 1),
#  ('months.', 1),
#  ('came', 1),
#  ('announced', 1),
#  ('cut', 1),
#  ('reserve', 1),
#  ('ratio', 1),
#  ('commercial', 1),
#  ('banks', 1),
#  ('fourth', 1),
#  ('year—a', 1),
#  ('liquidity', 1),
#  ('amid', 1),
#  ('general,', 1),
#  ('taking', 1),
#  ('stride.', 1),
#  ('tough', 1),
#  ('me.', 1),
#  ('received', 1),
#  ('payments', 1),
#  ('several', 1),
#  ('projects', 1),
#  ('bursts,”', 1),
#  ('social', 1),
#  ('media', 1),
#  ('platform', 1),
#  ('identified', 1),
#  ('securities', 1),
#  ('market’s', 1),
#  ('killed', 1),
#  ('projects.', 1),
#  ('returned', 1),
#  ('home,', 1),
#  ('village', 1),
#  ('me', 1),
#  ('how’s', 1),
#  ('My', 1),
#  ('answer,', 1),
#  ('sadly,', 1),
#  ('this—deleveraging,', 1),
#  ('bad', 1),
#  ('performance,', 1),
#  ('utterly', 1),
#  ('life.”', 1),
#  ('REUTERS/MARIANA', 1),
#  ('BAZO', 1),
#  ('Looking', 1),
#  ('devalued', 1),
#  ('many.', 1),
#  ('exporters', 1),
#  ('competitive,', 1),
#  ('makes', 1),
#  ('tougher', 1),
#  ('currency,', 1),
#  ('example', 1),
#  ('families', 1),
#  ('studying', 1),
#  ('abroad.', 1),
#  ('“We', 1),
#  ('kneeling', 1),
#  ('RMB', 1),
#  ('[renminbi]', 1),
#  ('stable', 1),
#  ('near', 1),
#  ('term.', 1),
#  ('Looks', 1),
#  ('Great', 1),
#  ('Depression', 1),
#  ('arrive,”', 1),
#  ('Weibo', 1),
#  ('Snacks,', 1),
#  ('Treats', 1),
#  ('due', 1),
#  ('daily', 1),
#  ('necessities.', 1),
#  ('yesterday', 1),
#  ('wanted', 1),
#  ('stock,”', 1),
#  ('female', 1),
#  ('northern', 1),
#  ('Hebei', 1),
#  ('province,', 1),
#  ('she’s', 1),
#  ('used', 1),
#  ('eating', 1),
#  ('every', 1),
#  ('day,', 1),
#  ('pecans,', 1),
#  ('commonly', 1),
#  ('sourced', 1),
#  ('her', 1),
#  ('more.', 1),
#  ('shop', 1),
#  ('owner,', 1),
#  ('‘Why', 1),
#  ('time?’', 1),
#  ('owner', 1),
#  ('it’s', 1),
#  ('continued,', 1),
#  ('“And', 1),
#  ('him,', 1),
#  ('‘What’s', 1),
#  ('relationship?’', 1),
#  ('imported', 1),
#  ('lots', 1),
#  ('overseas.', 1),
#  ('impact', 1),
#  ('war.”', 1),
#  ('Maine', 1),
#  ('lobster,', 1),
#  ('forget', 1),
#  ('it.', 1),
#  ('drivers', 1),
#  ('feeling', 1),
#  ('pinch,', 1),
#  ('putting', 1),
#  ('“I’ve', 1),
#  ('felt', 1),
#  ('peer-to-peer', 1),
#  ('lending', 1),
#  ('illegal', 1),
#  ('money-raising', 1),
#  ('crackdown,', 1),
#  ('bled', 1),
#  ('bunch', 1),
#  ('Now', 1),
#  ('drop', 1),
#  ('come', 1),
#  ('estate', 1),
#  ('market….', 1),
#  ('afford', 1),
#  ('car,”', 1),
#  ('Small', 1),
#  ('harder', 1),
#  ('larger', 1),
#  ('ones.', 1),
#  ('Caixin', 1),
#  ('Purchasing', 1),
#  ('Managers', 1),
#  ('Index,', 1),
#  ('gauge', 1),
#  ('sentiment', 1),
#  ('smaller,', 1),
#  ('private', 1),
#  ('official', 1),
#  ('PMI,', 1),
#  ('declined', 1),
#  ('50.6', 1),
#  ('August', 1),
#  ('month,', 1),
#  ('lowest', 1),
#  ('level', 1),
#  ('number', 1),
#  ('below', 1),
#  ('indicates', 1),
#  ('contraction.', 1),
#  ('REUTERS', 1),
#  ('soybean', 1),
#  ('Pessimism', 1),
#  ('People', 1),
#  ('aren’t', 1),
#  ('optimistic', 1),
#  ('ease', 1),
#  ('North', 1),
#  ('Free', 1),
#  ('renegotiated', 1),
#  ('Canada—now', 1),
#  ('brand-new', 1),
#  ('acronym—shows', 1),
#  ('formation', 1),
#  ('online', 1),
#  ('commenters', 1),
#  ('noted.', 1),
#  ('“Why', 1),
#  ('six', 1),
#  ('months?”', 1),
#  ('male', 1),
#  ('micro-blogging', 1),
#  ('site', 1),
#  ('southwestern', 1),
#  ('Sichuan', 1),
#  ('province.', 1),
#  ('His', 1),
#  ('driving', 1),
#  ('years—including', 1),
#  ('infrastructure,', 1),
#  ('demands—have', 1),
#  ('shown', 1),
#  ('signs.', 1),
#  ('“In', 1),
#  ('worrying,”', 1),
#  ('wrote.', 1),
#  ('launching', 1),
#  ('worldwide', 1),
#  ('bypass', 1),
#  ('WTO', 1),
#  ('[World', 1),
#  ('Organization]', 1),
#  ('something', 1),
#  ('new.', 1),
#  ('signed', 1),
#  ('cooperation', 1),
#  ('agreement.', 1),
#  ('economy‘', 1),
#  ('enter', 1),
#  ('market,', 1),
#  ('approval', 1),
#  ('countries…', 1),
#  ('Everyone', 1),
#  ('economy’', 1),
#  ('is.”', 1),
#  ('(The', 1),
#  ('asks', 1),
#  ('notify', 1),
#  ('“non-market”', 1),
#  ('economy,', 1),
#  ('say', 1),
#  ('deal.)', 1),
#  ('“Americans', 1),
#  ('circle.', 1),
#  ('round,', 1),
#  ('in,', 1),
#  ('Canada.', 1),
#  ('afraid', 1),
#  ('third', 1),
#  ('round', 1),
#  ('Europe,”', 1),
#  ('adjustments', 1),
#  ('listening', 1),
#  ('opinions', 1),
#  ('elites.”', 1),
#  ('US:', 1),
#  ('commerce', 1),
#  ('minister', 1),
#  ('SCMP', 1),
#  ('Amanda', 1),
#  ('Lee', 1),
#  ('cave', 1),
#  ('faces', 1),
#  ('exports,', 1),
#  ('Commerce', 1),
#  ('Shan', 1),
#  ('signalling', 1),
#  ('uncompromising', 1),
#  ('dealing', 1),
#  ('“There', 1),
#  ('view', 1),
#  ('They', 1),
#  ('don’t', 1),
#  ('culture', 1),
#  ('China,”', 1),
#  ('statement', 1),
#  ('published', 1),
#  ('Bloomberg', 1),
#  ('News.', 1),
#  ('unyielding', 1),
#  ('suffered', 1),
#  ('bullying', 1),
#  ('history,', 1),
#  ('succumbed', 1),
#  ('conditions.', 1),
#  ('out.', 1),
#  ('underestimate', 1),
#  ('will.”', 1),
#  ('release', 1),
#  ('white', 1),
#  ('paper', 1),
#  ('detailing', 1),
#  ('blamed', 1),
#  ('creating', 1),
#  ('painted', 1),
#  ('promoter', 1),
#  ('trade.', 1),
#  ('comments', 1),
#  ('Zhong,', 1),
#  ('ministry', 1),
#  ('possible', 1),
#  ('coincide', 1),
#  ('rapid', 1),
#  ('deterioration', 1),
#  ('ties', 1),
#  ('Washington.', 1),
#  ('ofCHINA’S', 1),
#  ...]
