# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv('dianping2.csv')
#df.head()

# %%
df
# Out:
#      Unnamed: 0  remark  price              title  flavour  environment  \
# 0             0     664   81.0       大院火老火锅(春熙路店)      9.0          9.1
# 1             1     701  111.0       大侠行江湖火锅(春熙店)      8.7          9.3
# 2             2     491   67.0       华兴九号辣铺(春熙总店)      8.6          9.2
# 3             3    1515   81.0        蜀韵蜀味火锅(春熙店)      8.7          9.1
# 4             4     675   87.0       月满大江火锅(总府路店)      9.0          9.1
# 5             5    1460   95.0     蜀小匠牛排火锅(春熙路总店)      8.1          7.5
# 6             6     278   96.0            鲜炎·炭火火锅      8.1          8.8
# 7             7    1266   78.0    凤望龙门老火锅(盐市口概念店)      9.0          9.0
# 8             8    1260   75.0       码头故事火锅(春熙路店)      8.8          9.1
# 9             9    3437   84.0       凤望龙门老火锅(春熙店)      8.6          8.6
# 10           10    1416   69.0    有拈头成都市井火锅(太古里店)      7.9          8.0
# 11           11    2139   90.0       春熙里老火锅(春熙总店)      8.5          9.0
# 12           12    1723   80.0     蜀胡记川西坝子(东门大桥店)      8.7          8.8
# 13           13    1182   78.0      重庆袁老四老火锅(香槟店)      8.3          8.5
# 14           14    1244   86.0        醉码头火锅(春熙路店)      8.8          9.1
# 15           15     280  125.0         大妙火锅(太古里店)      8.4          9.1
# 16           16    3323   88.0        巴蜀大将火锅(春熙店)      8.4          8.8
# 17           17      69   58.0    大蜀龙门火锅(红星路二段总店)      7.7          8.7
# 18           18     868   76.0  塘门英雄·美蛙鱼头火锅(春熙路店)      8.7          9.0
# 19           19     709   79.0    龙门飞鱼美蛙鱼头火锅(春熙店)      8.7          8.9
# 20           20    1632   78.0     野兽花园重庆火锅(太古里店)      8.0          8.8
# 21           21    2535   83.0      重庆袁老四老火锅(东升店)      8.3          8.3
# 22           22     145   68.0          老重庆金三角串串香      7.7          7.0
# 23           23    1707   84.0       巴蜀大将火锅(IFS店)      8.3          8.9
# 24           24      82   76.0       小春熙老火锅(春熙路店)      8.9          9.1
# 25           25     112   63.0              蜀财神火锅      9.0          9.1
# 26           26     807   81.0     重庆袁老四老火锅(太古里店)      8.2          8.6
# 27           27       1    NaN           谭二师路边麻辣烫      7.6          7.6
# 28           28     552   82.0     谭鸭血老火锅(王府井直营店)      7.7          8.1
# 29           29     528  102.0         梨园火锅(兰桂坊店)      8.2          9.1
# ..          ...     ...    ...                ...      ...          ...
# 284         284     428   79.0    龍爷翻大江老火锅(春熙路总店)      8.1          9.0
# 285         285     203   73.0       红花椒新火锅(春熙路店)      7.6          7.8
# 286         286     118   81.0            摆渡人老火锅铺      7.4          7.5
# 287         287     664    NaN       大院火老火锅(春熙路店)      NaN          NaN
# 288         288     701    NaN       大侠行江湖火锅(春熙店)      NaN          NaN
# 289         289     491    NaN       华兴九号辣铺(春熙总店)      NaN          NaN
# 290         290    1515    NaN        蜀韵蜀味火锅(春熙店)      NaN          NaN
# 291         291     675    NaN       月满大江火锅(总府路店)      NaN          NaN
# 292         292    1460    NaN     蜀小匠牛排火锅(春熙路总店)      NaN          NaN
# 293         293     278    NaN            鲜炎·炭火火锅      NaN          NaN
# 294         294    1266    NaN    凤望龙门老火锅(盐市口概念店)      NaN          NaN
# 295         295    1260    NaN       码头故事火锅(春熙路店)      NaN          NaN
# 296         296    3437    NaN       凤望龙门老火锅(春熙店)      NaN          NaN
# 297         297    1416    NaN    有拈头成都市井火锅(太古里店)      NaN          NaN
# 298         298    2139    NaN       春熙里老火锅(春熙总店)      NaN          NaN
# 299         299    1723    NaN     蜀胡记川西坝子(东门大桥店)      NaN          NaN
# 300         300    1182    NaN      重庆袁老四老火锅(香槟店)      NaN          NaN
# 301         301    1244    NaN        醉码头火锅(春熙路店)      NaN          NaN
# 302         302     280    NaN         大妙火锅(太古里店)      NaN          NaN
# 303         303    3323    NaN        巴蜀大将火锅(春熙店)      NaN          NaN
# 304         304      69    NaN    大蜀龙门火锅(红星路二段总店)      NaN          NaN
# 305         305     868    NaN  塘门英雄·美蛙鱼头火锅(春熙路店)      NaN          NaN
# 306         306     709    NaN    龙门飞鱼美蛙鱼头火锅(春熙店)      NaN          NaN
# 307         307    1632    NaN     野兽花园重庆火锅(太古里店)      NaN          NaN
# 308         308    2535    NaN      重庆袁老四老火锅(东升店)      NaN          NaN
# 309         309     145    NaN          老重庆金三角串串香      NaN          NaN
# 310         310    1707    NaN       巴蜀大将火锅(IFS店)      NaN          NaN
# 311         311      82    NaN       小春熙老火锅(春熙路店)      NaN          NaN
# 312         312     112    NaN              蜀财神火锅      NaN          NaN
# 313         313     807    NaN     重庆袁老四老火锅(太古里店)      NaN          NaN
#
#      service
# 0        9.1
# 1        9.0
# 2        9.0
# 3        8.9
# 4        8.9
# 5        8.3
# 6        8.1
# 7        8.6
# 8        8.9
# 9        8.6
# 10       7.7
# 11       8.6
# 12       8.9
# 13       7.8
# 14       8.6
# 15       8.4
# 16       8.5
# 17       8.3
# 18       8.8
# 19       8.8
# 20       8.1
# 21       7.8
# 22       7.4
# 23       8.8
# 24       8.7
# 25       8.9
# 26       8.1
# 27       7.6
# 28       7.4
# 29       8.6
# ..       ...
# 284      8.4
# 285      7.9
# 286      7.5
# 287      NaN
# 288      NaN
# 289      NaN
# 290      NaN
# 291      NaN
# 292      NaN
# 293      NaN
# 294      NaN
# 295      NaN
# 296      NaN
# 297      NaN
# 298      NaN
# 299      NaN
# 300      NaN
# 301      NaN
# 302      NaN
# 303      NaN
# 304      NaN
# 305      NaN
# 306      NaN
# 307      NaN
# 308      NaN
# 309      NaN
# 310      NaN
# 311      NaN
# 312      NaN
# 313      NaN
#
# [314 rows x 7 columns]

# %%
plt.rcParams['font.sans-serif']=['SimSun']
plt.rcParams['axes.unicode_minus']=False

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(20,10)) 

#plot price range count
price = pd.DataFrame(df['price'].value_counts())
ax1 = price.plot(kind = 'bar',color = '#46bc99',edgecolor = '#40b4e5',ax=axes[0,0],fontsize=20)
ax1.set_title("Price range count",fontsize=20)

#plot remark and flavour scatter
remark_flavour = df[['remark','flavour']]
ax4 = remark_flavour.plot(kind = 'scatter',x='flavour',y='remark',color = '#4ea1ef',ax=axes[0,1],s=60,fontsize=20)
ax4.set_title("Remark with flavour trend",fontsize=20)

#plot remark and environment scatter
remark_environment = df[['remark','environment']]
ax4 = remark_environment.plot(kind = 'scatter',x='environment',y='remark',color = '#ec9b31',ax=axes[1,0],s=60,fontsize=20)
ax4.set_title("Remark with environment trend",fontsize=20)

#plot remark and service scatter
remark_service = df[['remark','service']]
ax4 = remark_service.plot(kind = 'scatter',x='service',y='remark',color = '#f04e7c',ax=axes[1,1],s=60,fontsize=20)
ax4.set_title("Remark with service trend",fontsize=20)
# Out:
# Text(0.5,1,'Remark with service trend')

# %%
import pandas as pd

# %%
df = pd.read_csv('dianping2.csv')

# %%
#df.head()

# %%
a = df['flavour']
b = df['environment']
c = df['service']
d = df['comprehensive']

# %%
df['comprehensive'] = df['flavour'] + df['environment'] + df['service']

# %%
df.head()
# Out:
#    Unnamed: 0  remark  price         title  flavour  environment  service  \
# 0           0     664   81.0  大院火老火锅(春熙路店)      9.0          9.1      9.1
# 1           1     701  111.0  大侠行江湖火锅(春熙店)      8.7          9.3      9.0
# 2           2     491   67.0  华兴九号辣铺(春熙总店)      8.6          9.2      9.0
# 3           3    1515   81.0   蜀韵蜀味火锅(春熙店)      8.7          9.1      8.9
# 4           4     675   87.0  月满大江火锅(总府路店)      9.0          9.1      8.9
#
#    comprehensive
# 0           27.2
# 1           27.0
# 2           26.8
# 3           26.7
# 4           27.0

# %%
df.to_csv('dianping3.csv')

# %%
df = pd.read_csv('dianping3.csv')

# %%
#!pip install plotly

# %%
import plotly
import plotly.plotly as py

# %%
import plotly.graph_objs as go
pd_df1 = df.groupby(['title'])['comprehensive'].mean().reset_index().sort_values("comprehensive",ascending=False)

data = [go.Bar(x=pd_df1.title,
            y=pd_df1.comprehensive)]
plotly.offline.plot(data, filename='title_with_comprehensive_remark')
# Out:
# /Users/zengxingjie/anaconda3/lib/python3.6/site-packages/plotly/offline/offline.py:621: UserWarning:
#
# Your filename `title_with_comprehensive_remark` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/zengxingjie/Documents/GitHub/python-data-assignments/assignment2/title_with_comprehensive_remark.html'

# %%
import plotly.graph_objs as go
pd_df1 = df.groupby(['title'])['comprehensive'].mean().reset_index().sort_values("comprehensive",ascending=False)
#if you want to plot charts with sorted order, you need to sorted data first, then pass the data into function.

data = [go.Bar(x=pd_df1.title,
            y=pd_df1.comprehensive)]
plotly.offline.iplot(data, filename='title_with_comprehensive_remark')
